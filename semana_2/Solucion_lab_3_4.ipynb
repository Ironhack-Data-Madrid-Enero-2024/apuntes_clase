# %% [markdown]
# # Lab | Data Structuring and Combining Data
#
# # Challenge 1: Combining Data
#
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the following links:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2_clean.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3_clean.csv
#
# Combine the data from the three dataframes into a single dataframe, named "customer_data", using appropriate merging, concatenating, and joining techniques.
#
# Verify that the customer_data dataframe contains all the rows and columns from the three original dataframes.

# %%
import pandas as pd

# enseñe todas las columnas y filas
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1_clean.csv')

df1.head()
# Out:
#   customer       state gender             education  customer_lifetime_value  \
# 0  RB50392  Washington      F                Master                   779946
# 1  QZ44356     Arizona      F              Bachelor                   697953
# 2  AI49188      Nevada      F              Bachelor                  1288743
# 3  WW63253  California      M              Bachelor                   764586
# 4  GA49547  Washington      M  High School or Below                   536307
#
#    income  monthly_premium_auto  number_of_open_complaints     policy_type  \
# 0       0                  1000                          0   Personal Auto
# 1       0                    94                          0   Personal Auto
# 2   48767                   108                          0   Personal Auto
# 3       0                   106                          0  Corporate Auto
# 4   36357                    68                          0   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2_clean.csv')


df2.columns = [e.lower().replace(' ', '_') for e in df2.columns] 


df2.rename(columns={'st': 'state'}, inplace=True)


df2.head()
# Out:
#   customer       state gender             education customer_lifetime_value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
df3 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3_clean.csv')

df3.columns = [e.lower().replace(' ', '_') for e in df3.columns] 


df3.rename(columns={'st': 'state'}, inplace=True)


df3.head()
# Out:
#   customer       state gender             education customer_lifetime_value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
df = pd.concat([df1, df2, df3], ignore_index=True)

df.head()
# Out:
#   customer       state gender             education customer_lifetime_value  \
# 0  RB50392  Washington      F                Master                  779946
# 1  QZ44356     Arizona      F              Bachelor                  697953
# 2  AI49188      Nevada      F              Bachelor                 1288743
# 3  WW63253  California      M              Bachelor                  764586
# 4  GA49547  Washington      M  High School or Below                  536307
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                         0   Personal Auto
# 1      0.0                  94.0                         0   Personal Auto
# 2  48767.0                 108.0                         0   Personal Auto
# 3      0.0                 106.0                         0  Corporate Auto
# 4  36357.0                  68.0                         0   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %% [markdown]
# # Challenge 2: Structuring Data
#
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv')

df.head()
# Out:
#    unnamed:_0 customer       state  customer_lifetime_value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective_to_date employmentstatus gender  income  \
# 0     Basic   College        2011-02-18         Employed      M   48029
# 1     Basic   College        2011-01-18       Unemployed      F       0
# 2     Basic  Bachelor        2011-02-10         Employed      M   22139
# 3  Extended   College        2011-01-11         Employed      M   49078
# 4   Premium  Bachelor        2011-01-17    Medical Leave      F   23675
#
#   location_code marital_status  monthly_premium_auto  months_since_last_claim  \
# ...

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
df.pivot_table(values = 'total_claim_amount',
               index = 'sales_channel',
               aggfunc='sum').round(2).reset_index()
# Out:
#   sales_channel  total_claim_amount
# 0         Agent          1810226.82
# 1        Branch          1301204.00
# 2   Call Center           926600.82
# 3           Web           706600.04

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
df.pivot_table(values = 'customer_lifetime_value',
               index = ['gender', 'education'],
               aggfunc='mean').round(2).reset_index()
# Out:
#   gender             education  customer_lifetime_value
# 0      F              Bachelor                  7874.27
# 1      F               College                  7748.82
# 2      F                Doctor                  7328.51
# 3      F  High School or Below                  8675.22
# 4      F                Master                  8157.05
# 5      M              Bachelor                  7703.60
# 6      M               College                  8052.46
# 7      M                Doctor                  7415.33
# 8      M  High School or Below                  8149.69
# 9      M                Master                  8168.83

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %%
df.head()
# Out:
#    unnamed:_0 customer       state  customer_lifetime_value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective_to_date employmentstatus gender  income  \
# 0     Basic   College        2011-02-18         Employed      M   48029
# 1     Basic   College        2011-01-18       Unemployed      F       0
# 2     Basic  Bachelor        2011-02-10         Employed      M   22139
# 3  Extended   College        2011-01-11         Employed      M   49078
# 4   Premium  Bachelor        2011-01-17    Medical Leave      F   23675
#
#   location_code marital_status  monthly_premium_auto  months_since_last_claim  \
# ...

# %%
df.pivot_table(values = 'number_of_open_complaints',
               index = ['month', 'policy_type'],
               aggfunc='count').round(2).reset_index()
# Out:
#    month     policy_type  number_of_open_complaints
# 0      1  Corporate Auto                       1252
# 1      1   Personal Auto                       4329
# 2      1    Special Auto                        237
# 3      2  Corporate Auto                       1089
# 4      2   Personal Auto                       3799
# 5      2    Special Auto                        204

# %%
df.pivot_table(values = 'number_of_open_complaints',
               index = ['month'],
               columns = ['policy_type'],
               aggfunc='count').round(2).reset_index()
# Out:
# policy_type  month  Corporate Auto  Personal Auto  Special Auto
# 0                1            1252           4329           237
# 1                2            1089           3799           204

# %% [markdown]
# # Lab | Data Aggregation and Filtering
#
# In this challenge, we will continue to work with customer data from an insurance company. We will use the dataset called marketing_customer_analysis_clean.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing first data cleaning, formatting, and structuring.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv')

# %%
df.head()
# Out:
#    unnamed:_0 customer       state  customer_lifetime_value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective_to_date employmentstatus gender  income  \
# 0     Basic   College        2011-02-18         Employed      M   48029
# 1     Basic   College        2011-01-18       Unemployed      F       0
# 2     Basic  Bachelor        2011-02-10         Employed      M   22139
# 3  Extended   College        2011-01-11         Employed      M   49078
# 4   Premium  Bachelor        2011-01-17    Medical Leave      F   23675
#
#   location_code marital_status  monthly_premium_auto  months_since_last_claim  \
# ...

# %% [markdown]
# 1. Create a new DataFrame that only includes customers who have a total_claim_amount greater than $1,000 and have a response of "Yes" to the last marketing campaign. How many customers were there?

# %%
df1 = df[(df.total_claim_amount>1000) & (df.response=='Yes')]

df1.head()
# Out:
#      unnamed:_0 customer       state  customer_lifetime_value response  \
# 189         189  OK31456  California             11009.130490      Yes
# 236         236  YJ16163      Oregon             11009.130490      Yes
# 419         419  GW43195      Oregon             25807.063000      Yes
# 442         442  IP94270     Arizona             13736.132500      Yes
# 587         587  FJ28407  California              5619.689084      Yes
#
#      coverage             education effective_to_date employmentstatus gender  \
# 189   Premium              Bachelor        2011-01-24         Employed      F
# 236   Premium              Bachelor        2011-01-24         Employed      F
# 419  Extended               College        2011-02-13         Employed      F
# 442   Premium                Master        2011-02-13         Disabled      F
# 587   Premium  High School or Below        2011-01-26       Unemployed      M
#
#      income location_code marital_status  monthly_premium_auto  \
# ...

# %% [markdown]
# 2. Using the original dataframe, analyze the average total_claim_amount by each policy type and gender for customers who have responded "Yes" to the last marketing campaign. Write your conclusions.

# %%
df.head()
# Out:
#    unnamed:_0 customer       state  customer_lifetime_value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective_to_date employmentstatus gender  income  \
# 0     Basic   College        2011-02-18         Employed      M   48029
# 1     Basic   College        2011-01-18       Unemployed      F       0
# 2     Basic  Bachelor        2011-02-10         Employed      M   22139
# 3  Extended   College        2011-01-11         Employed      M   49078
# 4   Premium  Bachelor        2011-01-17    Medical Leave      F   23675
#
#   location_code marital_status  monthly_premium_auto  months_since_last_claim  \
# ...

# %%
yes = df[df.response=='Yes']

yes.head()
# Out:
#     unnamed:_0 customer       state  customer_lifetime_value response  \
# 3            3  XL78013      Oregon             22332.439460      Yes
# 8            8  FM55990  California              5989.773931      Yes
# 15          15  CW49887  California              4626.801093      Yes
# 19          19  NJ54277  California              3746.751625      Yes
# 27          27  MQ68407      Oregon              4376.363592      Yes
#
#     coverage education effective_to_date employmentstatus gender  income  \
# 3   Extended   College        2011-01-11         Employed      M   49078
# 8    Premium   College        2011-01-19         Employed      M   66839
# 15     Basic    Master        2011-01-16         Employed      F   79487
# 19  Extended   College        2011-02-26         Employed      F   41479
# 27   Premium  Bachelor        2011-02-28         Employed      F   63774
#
#    location_code marital_status  monthly_premium_auto  \
# ...

# %%
yes.groupby(['policy_type', 'gender'])['total_claim_amount'].mean().reset_index()
# Out:
#       policy_type gender  total_claim_amount
# 0  Corporate Auto      F          433.738499
# 1  Corporate Auto      M          408.582459
# 2   Personal Auto      F          452.965929
# 3   Personal Auto      M          457.010178
# 4    Special Auto      F          453.280164
# 5    Special Auto      M          429.527942

# %%
df[df.response=='Yes'].groupby(['policy_type', 'gender'])['total_claim_amount'].mean().reset_index()
# Out:
#       policy_type gender  total_claim_amount
# 0  Corporate Auto      F          433.738499
# 1  Corporate Auto      M          408.582459
# 2   Personal Auto      F          452.965929
# 3   Personal Auto      M          457.010178
# 4    Special Auto      F          453.280164
# 5    Special Auto      M          429.527942

# %%
df[(df.response=='Yes') & (df.total_claim_amount>1000)].groupby(['policy_type', 'gender'])['total_claim_amount'].mean().reset_index()
# Out:
#       policy_type gender  total_claim_amount
# 0  Corporate Auto      F         1138.400000
# 1  Corporate Auto      M         1171.150007
# 2   Personal Auto      F         1214.853805
# 3   Personal Auto      M         1137.861443
# 4    Special Auto      F         1358.400000
# 5    Special Auto      M         1017.500015

# %% [markdown]
# 3. Analyze the total number of customers who have policies in each state, and then filter the results to only include states where there are more than 500 customers.

# %%
df_custo = df.groupby('state')['customer'].count().reset_index()

df_custo
# Out:
#         state  customer
# 0     Arizona      1937
# 1  California      4183
# 2      Nevada       993
# 3      Oregon      2909
# 4  Washington       888

# %%
df_custo[df_custo.customer>500]
# Out:
#         state  customer
# 0     Arizona      1937
# 1  California      4183
# 2      Nevada       993
# 3      Oregon      2909
# 4  Washington       888

# %%
nuevo = df[(df.response=='Yes') & (df.total_claim_amount>1000)].groupby(['policy_type', 'gender'])['total_claim_amount'].mean()

# %%
nuevo.index
# Out:
# MultiIndex([('Corporate Auto', 'F'),
#             ('Corporate Auto', 'M'),
#             ( 'Personal Auto', 'F'),
#             ( 'Personal Auto', 'M'),
#             (  'Special Auto', 'F'),
#             (  'Special Auto', 'M')],
#            names=['policy_type', 'gender'])

# %%
nuevo.loc[( 'Personal Auto', 'M')]
# Out:
# 1137.8614429545453

# %%
nuevo[nuevo>1200]
# Out:
# policy_type    gender
# Personal Auto  F         1214.853805
# Special Auto   F         1358.400000
# Name: total_claim_amount, dtype: float64

# %% [markdown]
# 4. Find the maximum, minimum, and median customer lifetime value by education level and gender. Write your conclusions.

# %%
df.groupby(['education', 'gender'])['customer_lifetime_value'].agg(['min', 'mean', 'max'])
# Out:
#                                      min         mean          max
# education            gender
# Bachelor             F       1904.000852  7874.269478  73225.95652
#                      M       1898.007675  7703.601675  67907.27050
# College              F       1898.683686  7748.823325  61850.18803
#                      M       1918.119700  8052.459288  61134.68307
# Doctor               F       2395.570000  7328.508916  44856.11397
#                      M       2267.604038  7415.333638  32677.34284
# High School or Below F       2144.921535  8675.220201  55277.44589
#                      M       1940.981221  8149.687783  83325.38119
# Master               F       2417.777032  8157.053154  51016.06704
#                      M       2272.307310  8168.832659  50568.25912

# %%
df.groupby(['education', 'gender']).agg({'customer_lifetime_value': ['min', 'mean', 'max']})
# Out:
#                             customer_lifetime_value
#                                                 min         mean          max
# education            gender
# Bachelor             F                  1904.000852  7874.269478  73225.95652
#                      M                  1898.007675  7703.601675  67907.27050
# College              F                  1898.683686  7748.823325  61850.18803
#                      M                  1918.119700  8052.459288  61134.68307
# Doctor               F                  2395.570000  7328.508916  44856.11397
#                      M                  2267.604038  7415.333638  32677.34284
# High School or Below F                  2144.921535  8675.220201  55277.44589
#                      M                  1940.981221  8149.687783  83325.38119
# Master               F                  2417.777032  8157.053154  51016.06704
#                      M                  2272.307310  8168.832659  50568.25912

# %% [markdown]
# 5. The marketing team wants to analyze the number of policies sold by state and month.
#
# Present the data in a table where the months are arranged as columns and the states are arranged as rows.

# %%
df.groupby(['state', 'month'])['number_of_policies'].count().reset_index()
# Out:
#         state  month  number_of_policies
# 0     Arizona      1                1008
# 1     Arizona      2                 929
# 2  California      1                2231
# 3  California      2                1952
# 4      Nevada      1                 551
# 5      Nevada      2                 442
# 6      Oregon      1                1565
# 7      Oregon      2                1344
# 8  Washington      1                 463
# 9  Washington      2                 425

# %% [markdown]
# 6. Display a new DataFrame that contains the number of policies sold by month by state for the top 3 states with the highest number of policies sold.
#
# *Hint:*
# - *To accomplish this, you will first need to group the data by state and month, then count the number of policies sold for each group. Afterwards, you will need to sort the data by the count of policies sold in descending order.*
# - *Next, you will select the top 3 states with the highest number of policies sold.*
# - *Finally, you will create a new DataFrame that contains the number of policies sold by month for each of the top 3 states.*

# %%
grupo = df.groupby(['state', 'month'])['number_of_policies'].count().reset_index()

# %%
grupo
# Out:
#         state  month  number_of_policies
# 0     Arizona      1                1008
# 1     Arizona      2                 929
# 2  California      1                2231
# 3  California      2                1952
# 4      Nevada      1                 551
# 5      Nevada      2                 442
# 6      Oregon      1                1565
# 7      Oregon      2                1344
# 8  Washington      1                 463
# 9  Washington      2                 425

# %%
ordenado = grupo.sort_values(by='number_of_policies', ascending=False)

# %%
ordenado.state
# Out:
# 2    California
# 3    California
# 6        Oregon
# 7        Oregon
# 0       Arizona
# 1       Arizona
# 4        Nevada
# 8    Washington
# 5        Nevada
# 9    Washington
# Name: state, dtype: object

# %%
ordenado.state.unique()
# Out:
# array(['California', 'Oregon', 'Arizona', 'Nevada', 'Washington'],
#       dtype=object)

# %%
ordenado.state.unique()[:3]
# Out:
# array(['California', 'Oregon', 'Arizona'], dtype=object)

# %%
grupo = df.groupby(['state', 'month'])['number_of_policies'].sum().reset_index()

ordenado = grupo.sort_values(by='number_of_policies', ascending=False)

ordenado.state.unique()[:3]
# Out:
# array(['California', 'Oregon', 'Arizona'], dtype=object)

# %%
grupo = df.groupby('state')['number_of_policies'].sum().reset_index()

ordenado = grupo.sort_values(by='number_of_policies', ascending=False)


ordenado.head(3)
# Out:
#         state  number_of_policies
# 1  California               12567
# 3      Oregon                8666
# 0     Arizona                5916

# %% [markdown]
# 7. The marketing team wants to analyze the effect of different marketing channels on the customer response rate.
#
# Hint: You can use melt to unpivot the data and create a table that shows the customer response rate (those who responded "Yes") by marketing channel.

# %%
df.response = df.response.apply(lambda x: 1 if x=='Yes' else 0)

# %%
df.response.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# Name: response, dtype: int64

# %%
melteado = pd.melt(df, id_vars=['sales_channel'], value_vars=['response'])

# %%
melteado.head()
# Out:
#   sales_channel  variable  value
# 0         Agent  response      0
# 1   Call Center  response      0
# 2   Call Center  response      0
# 3        Branch  response      1
# 4        Branch  response      0

# %%
melteado.groupby('sales_channel')['value'].sum().reset_index()
# Out:
#   sales_channel  value
# 0         Agent    742
# 1        Branch    326
# 2   Call Center    221
# 3           Web    177
